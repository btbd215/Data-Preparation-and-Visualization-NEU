# %% [markdown]
# ### Name : Bùi Phương Thảo
# ### ID: 11215341
# ### class: DSEB 63

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\KyThuat88\Downloads\Product_Price.xlsx")
df
# Out:
#   Unnamed: 0  Unnamed: 1   2008   2009   2010   2011   2012  2013  2014
# 0  Product A         NaN  395.0  420.0  425.0  390.0  300.0   270   260
# 1  Product B         NaN  360.0  400.0  410.0  375.0  290.0   260   250
# 2  Product C         NaN    NaN    NaN  100.0  180.0  198.0   240   180
# 3  Product D         NaN    NaN    NaN    NaN  160.0  260.0   220   215
# 4  Product E         NaN    NaN    NaN    NaN    NaN    NaN    98   210

# %%
df.drop('Unnamed: 1', axis = 1, inplace = True)

# %%
df = df.rename(columns = {'Unnamed: 0':'Pro'})

# %%
df.columns
# Out:
# Index(['Pro', 2008, 2009, 2010, 2011, 2012, 2013, 2014], dtype='object')

# %%
df.set_index('Pro', inplace = True)
df
# Out:
#             2008   2009   2010   2011   2012  2013  2014
# Pro
# Product A  395.0  420.0  425.0  390.0  300.0   270   260
# Product B  360.0  400.0  410.0  375.0  290.0   260   250
# Product C    NaN    NaN  100.0  180.0  198.0   240   180
# Product D    NaN    NaN    NaN  160.0  260.0   220   215
# Product E    NaN    NaN    NaN    NaN    NaN    98   210

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df.T)
ax.legend(['Product A','Product B','Product C','Product D','Product E'])
ax.set_yticks([0,100,200,300,400,500])
ax.set_yticklabels(str(x) + '$' for x in ax.get_yticks())
# Out:
# [Text(0, 0, '0$'),
#  Text(0, 100, '100$'),
#  Text(0, 200, '200$'),
#  Text(0, 300, '300$'),
#  Text(0, 400, '400$'),
#  Text(0, 500, '500$')]

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df.T, color = 'grey', linewidth = 3.4)
#ax.legend(['Product A','Product B','Product C','Product D','Product E'])
ax.set_yticks([0,100,200,300,400,500])
ax.set_yticklabels(str(x) + '$' for x in ax.get_yticks())
ax.spines[['top','right']].set_visible(False)
ax.spines[['bottom','left']].set_color('#DCDCDC')
line = ax.lines
xa = line[0].get_xdata()[2:]
ya = line[0].get_ydata()[2:]
ax.plot(xa,ya,color = 'blue')
xb = line[1].get_xdata()[2:]
yb = line[1].get_ydata()[2:]
ax.plot(xb,yb,color = 'blue')
ax.text(line[0].get_xdata()[0] - 0.2, 400, 'A',weight = 'bold', color = 'grey', size = 14)
ax.text(line[1].get_xdata()[0] - 0.2, line[1].get_ydata()[0], 'B',weight = 'bold', color = 'grey', size = 14)
ax.text(line[2].get_xdata()[2] - 0.2, line[2].get_ydata()[2], 'C',weight = 'bold', color = 'grey', size = 14)
ax.text(line[3].get_xdata()[3] - 0.2, line[3].get_ydata()[3] - 20, 'D',weight = 'bold', color = 'grey', size = 14)
ax.text(line[4].get_xdata()[5] - 0.2, line[4].get_ydata()[5], 'E',weight = 'bold', color = 'grey', size = 14)
line[2].set_markevery([2])
line[2].set_marker('o')
line[2].set_markersize(9)
line[2].set_markerfacecolor('blue')
ax.set_title('Average price per year',size=18)
# Out:
# Text(0.5, 1.0, 'Average price per year')

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df.T, color = 'grey', linewidth = 3.4)
#ax.legend(['Product A','Product B','Product C','Product D','Product E'])
ax.set_yticks([0,100,200,300,400,500])
ax.set_yticklabels(str(x) + '$' for x in ax.get_yticks())
ax.spines[['top','right']].set_visible(False)
ax.spines[['bottom','left']].set_color('#DCDCDC')
line = ax.lines
xa = line[0].get_xdata()[2:]
ya = line[0].get_ydata()[2:]
ax.plot(xa,ya,color = 'black')
xb = line[1].get_xdata()[2:]
yb = line[1].get_ydata()[2:]
ax.plot(xb,yb,color = 'black')
ax.text(line[0].get_xdata()[0] - 0.2, 400, 'A',weight = 'bold', color = 'grey', size = 14)
ax.text(line[1].get_xdata()[0] - 0.2, line[1].get_ydata()[0], 'B',weight = 'bold', color = 'grey', size = 14)
ax.text(line[2].get_xdata()[2] - 0.2, line[2].get_ydata()[2], 'C',weight = 'bold', color = 'grey', size = 14)
ax.text(line[3].get_xdata()[3] - 0.2, line[3].get_ydata()[3] - 20, 'D',weight = 'bold', color = 'grey', size = 14)
ax.text(line[4].get_xdata()[5] - 0.2, line[4].get_ydata()[5], 'E',weight = 'bold', color = 'grey', size = 14)
x0 = line[0].get_xdata()[:2]
y0 = line[0].get_ydata()[:2]
ax.plot(x0,y0,color = 'blue')
x1 = line[1].get_xdata()[:2]
y1 = line[1].get_ydata()[:2]
ax.plot(x1,y1,color = 'blue')
xdata2 = line[2].get_xdata()[2:4]
ydata2 = line[2].get_ydata()[2:4]
ax.plot(xdata2,ydata2,color='blue')
xdata2 = line[2].get_xdata()[5:]
ydata2 = line[2].get_ydata()[5:]
ax.plot(xdata2,ydata2,color='black')
xdata3 = line[3].get_xdata()[3:5]
ydata3 = line[3].get_ydata()[3:5]
ax.plot(xdata3,ydata3,color='blue')
xdata3 = line[3].get_xdata()[4:]
ydata3 = line[3].get_ydata()[4:]
ax.plot(xdata3,ydata3,color='black')
xdata4 = line[4].get_xdata()[5:]
ydata4 = line[4].get_ydata()[5:]
ax.plot(xdata4,ydata4,color='blue')
ax.set_title('Average retail price over time',size=18)
# Out:
# Text(0.5, 1.0, 'Average retail price over time')

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df.T, color = 'grey', linewidth = 3.4)
#ax.legend(['Product A','Product B','Product C','Product D','Product E'])
ax.set_yticks([0,100,200,300,400,500])
ax.set_yticklabels(str(x) + '$' for x in ax.get_yticks())
ax.spines[['top','right']].set_visible(False)
ax.spines[['bottom','left']].set_color('#DCDCDC')
line = ax.lines
ax.text(line[0].get_xdata()[0] - 0.2, 400, 'A',weight = 'bold', color = 'grey', size = 14)
ax.text(line[1].get_xdata()[0] - 0.2, line[1].get_ydata()[0], 'B',weight = 'bold', color = 'grey', size = 14)
ax.text(line[2].get_xdata()[2] - 0.2, line[2].get_ydata()[2], 'C',weight = 'bold', color = 'grey', size = 14)
ax.text(line[3].get_xdata()[3] - 0.2, line[3].get_ydata()[3] - 20, 'D',weight = 'bold', color = 'grey', size = 14)
ax.text(line[4].get_xdata()[5] - 0.2, line[4].get_ydata()[5], 'E',weight = 'bold', color = 'grey', size = 14)
for i in range(5):
    line[i].set_markevery([6])
    line[i].set_marker('o')
    line[i].set_markersize(9)
    line[i].set_markerfacecolor('blue')
ax.get_xticklabels()[7].set_color('blue')
ax.set_title('Average retail product price per year',size=18)
# Out:
# Text(0.5, 1.0, 'Average retail product price per year')

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.plot(df.T, color = 'grey', linewidth = 3.4)
#ax.legend(['Product A','Product B','Product C','Product D','Product E'])
ax.set_yticks([0,100,200,300,400,500])
ax.set_yticklabels(str(x) + '$' for x in ax.get_yticks())
ax.spines[['top','right']].set_visible(False)
ax.spines[['bottom','left']].set_color('#DCDCDC')
line = ax.lines
ax.text(line[0].get_xdata()[0] - 0.2, 400, 'A',weight = 'bold', color = 'grey', size = 14)
ax.text(line[1].get_xdata()[0] - 0.2, line[1].get_ydata()[0], 'B',weight = 'bold', color = 'grey', size = 14)
ax.text(line[2].get_xdata()[2] - 0.2, line[2].get_ydata()[2], 'C',weight = 'bold', color = 'grey', size = 14)
ax.text(line[3].get_xdata()[3] - 0.2, line[3].get_ydata()[3] - 20, 'D',weight = 'bold', color = 'grey', size = 14)
ax.text(line[4].get_xdata()[5] - 0.2, line[4].get_ydata()[5], 'E',weight = 'bold', color = 'grey', size = 14)
# for i in range(5):
#     line[i].set_markevery([6])
#     line[i].set_marker('o')
#     line[i].set_markersize(9)
#     line[i].set_markerfacecolor('blue')
ax.axhline(y=200,linewidth=50,alpha=0.1)
ax.text(2007.9,200,'Recommended range', color = 'blue', weight = 'bold', size = 15)
ax.plot(2014,225,'ro')
ax.annotate('AVG',(2014.1,220))
ax.set_title('retail price over time',size=18)
# Out:
# Text(0.5, 1.0, 'retail price over time')

# %%
df1 = pd.read_csv(r"C:\Users\KyThuat88\Downloads\covid_avg_deaths.csv")
df1
# Out:
#     Month  New_deaths
# 0       1           0
# 1       2           0
# 2       3          77
# 3       4        1844
# 4       5        1448
# 5       6         785
# 6       7         769
# 7       8        1020
# 8       9         739
# 9      10         751
# 10     11        1225
# 11     12        2247

# %%
df1['New_deaths'].sum()
# Out:
# 10905

# %%
df1.set_index('Month', inplace = True)

# %%
df1
# Out:
#        New_deaths
# Month
# 1               0
# 2               0
# 3              77
# 4            1844
# 5            1448
# 6             785
# 7             769
# 8            1020
# 9             739
# 10            751
# 11           1225
# 12           2247

# %%
fig,ax = plt.subplots(figsize = (10,5))
ax.plot(df1, color = 'pink')
ax.spines[['top','bottom','left','right']].set_visible(False)
ax.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
line = ax.lines[0]
x0 = line.get_xdata()[:3]
y0 = line.get_ydata()[:3]
allx = line.get_xdata()
ally = line.get_ydata()
ax.plot(x0,y0,color = 'red')
ax.text(1.2,-120,'Jan-March', color = 'red', size = 13)
ax.text(x0[0] - 0.3,0, y0[0], color = 'grey', size = 12)
ax.text(allx[3] - 0.3,ally[3] + 100, ally[3], color = 'grey', size = 12)
ax.text(allx[-1] - 0.3,ally[-1] + 100, ally[-1], color = 'grey', size = 12)
cumsum = y0.cumsum()
cumall = ally.cumsum()
ax.hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = cumall[-1]/1211.6, color = 'pink', lw = 4)
ax.hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = cumsum[-1]/12.5, color = 'red', lw = 4)
ax.text(allx[6],1844 + 100, cumsum[-1], color = 'red', size = 12, weight = 'bold')
# Out:
# Text(7, 1944, '77')

# %%
allx = line.get_xdata()
ally = line.get_ydata()
fig, ax = plt.subplots(4, 1,figsize = (10,10))
fig.tight_layout()
for i in range(0,4):
    ax[i].plot(df1, color = 'pink')
    ax[i].spines[['top','bottom','left','right']].set_visible(False)
    ax[i].tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    line = ax[i].lines[0]
    allx = line.get_xdata()
    ally = line.get_ydata()
    ax[i].hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = cumall[-1]/1211.6, color = 'pink', lw = 4)
#graph1
line0 = ax[0].lines[0]
x0 = line0.get_xdata()[:3]
y0 = line0.get_ydata()[:3]
cumsum0 = y0.cumsum()
ax[0].plot(x0,y0,color = 'red')
ax[0].text(1.2,-200,'Jan-March', color = 'red', size = 13)
ax[0].text(x0[0] - 0.3,0, y0[0], color = 'grey', size = 12)
ax[0].text(allx[3] - 0.3,ally[3] + 100, ally[3], color = 'grey', size = 12)
ax[0].text(allx[-1] - 0.3,ally[-1] + 100, ally[-1], color = 'grey', size = 12)
ax[0].hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = cumsum0[-1]/12.5, color = 'red', lw = 4)
ax[0].text(allx[6],1844 + 100, cumsum0[-1] * 30, color = 'red', size = 12, weight = 'bold')
#graph2
x1 = line0.get_xdata()[2:6]
y1 = line0.get_ydata()[2:6]
cumsum1 = y1.cumsum()
ax[1].plot(x1,y1,color = 'red')
ax[1].hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = (cumsum0[-1] + cumsum1[-1])/570, color = 'red', lw = 4)
ax[1].text(allx[6],1844 + 100, (cumsum0[-1] + cumsum1[-1]) * 30, color = 'red', size = 12, weight = 'bold')
ax[1].text(4,1000,'Mar - Jun', color = 'red', size = 13)
#graph3
x2 = line0.get_xdata()[5:10]
y2 = line0.get_ydata()[5:10]
cumsum2 = y2.cumsum()
ax[2].plot(x2,y2,color = 'red')
ax[2].hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = (cumsum0[-1] + cumsum1[-1] + cumsum2[-1])/1000, color = 'red', lw = 4)
ax[2].text(allx[6],1844 + 100, (cumsum0[-1] + cumsum1[-1] + cumsum2[-1]) * 30, color = 'red', size = 12, weight = 'bold')
ax[2].text(7.5,600,'Jun - Oct', color = 'red', size = 13)
#graph4
x3 = line0.get_xdata()[9:]
y3 = line0.get_ydata()[9:]
cumsum3 = y3.cumsum()
ax[3].plot(x3,y3,color = 'red')
ax[3].hlines(y = 1844, xmin = cumall[-1]/1817.5, xmax = (cumsum0[-1] + cumsum1[-1] + cumsum2[-1] + cumsum3[-1])/1399, color = 'red', lw = 4)
ax[3].text(allx[6],1844 + 100, (cumsum0[-1] + cumsum1[-1] + cumsum2[-1] + cumsum3[-1]) * 23, color = 'red', size = 12, weight = 'bold')
ax[3].text(11,600,'Oct - Dec', color = 'red', size = 13)

#ax[0].set_title('The virus kill 851 people each day',loc = 'left', weight = 'bold', size = 14)
ax[0].text(x=0.4, y = 2680, s = 'The virus kill 851 people each day', size = 16, weight = 'bold')
ax[0].text(x=0.4, y = 2350, s = 'Average number of daily death per month in the US', size = 13)
# Out:
# Text(0.4, 2350, 'Average number of daily death per month in the US')

# %%
ax[0].get_ylim()
# Out:
# (-112.35000000000001, 2359.35)

# %%
ax[0].get_xlim()
# Out:
# (0.44999999999999996, 12.55)
